# %% [markdown]
# ## Exploring the data

# %% [markdown]
# So let's learn how we set up the data.

# %%
#default_exp model

# %%
#hide
import os, sys, warnings

# %%
#hide
root = "D:/data_sets/24_garden"
os.chdir(root)

# %%
#hide
warnings.filterwarnings("ignore", category=RuntimeWarning) 
warnings.filterwarnings("ignore", category=UserWarning)

# %%
#export
from fastai2.vision.all import *
from garden.utils import *
from garden.data import *

# %%
splitter = IndexSplitter(range(12753, len(data)))

block = DataBlock(blocks=(ImageBlock, CategoryBlock), 
                  get_items=get_items,
                  get_x=get_x,
                  get_y=get_y,
                  splitter=splitter,
                  item_tfms=[Resize(224)],
                  batch_tfms=[*aug_transforms()])

# %%
dls = block.dataloaders('', bs=64,num_workers=0)

# %%
dls.show_batch()

# %%
lr = 1e-2
def opt_func(ps, lr=defaults.lr): ranger(ps,lr, mom=0.98, wd=0.02, eps=1e-06, 
                  sqr_mom=0.99, beta=0.0, decouple_wd=True)
net1 = xresnet50(pretrained=False, sa=True, act_cls=Mish)
learn1 = Learner(dls, net1, opt_func=ranger, metrics=accuracy)
learn1 = learn1.fit_one_cycle(1, 2e-2)
learn1 = learn1.fit_one_cycle(3, 1e-3)
learn1 = learn1.fit_one_cycle(1, 1e-5)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='2', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/2 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='44' class='' max='199', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       22.11% [44/199 00:49<02:53 4.9704]
#     </div>

# %%
learn1.fit_one_cycle(1, 1e-5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.959749</td>
#       <td>2.012299</td>
#       <td>0.470366</td>
#       <td>04:29</td>
#     </tr>
#   </tbody>
# </table>

# %%
preds1, targs1 = learn1.get_preds()

# %%
net2 = xresnet50(pretrained=False, sa=True, act_cls=Mish)
learn2 = Learner(dls, net2, opt_func=ranger, metrics=accuracy)
learn2.fit_flat_cos(5, 1e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.767329</td>
#       <td>2.596680</td>
#       <td>0.332974</td>
#       <td>04:27</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.277290</td>
#       <td>2.419879</td>
#       <td>0.394935</td>
#       <td>04:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.870325</td>
#       <td>2.629478</td>
#       <td>0.387392</td>
#       <td>04:14</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.578521</td>
#       <td>1.899649</td>
#       <td>0.507274</td>
#       <td>04:15</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.055937</td>
#       <td>1.088814</td>
#       <td>0.713901</td>
#       <td>04:15</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.dls.

# %%
preds2, _ = learn2.get_preds()

# %%
#Combining predictions

# %%
preds = torch.stack((preds1, preds2))
preds.std()
# Out:
# tensor(0.0241)

# %%
preds.shape
# Out:
# torch.Size([2, 3712, 1000])

# %%
import numpy as np
np.corrcoef(preds.view(preds.shape[0], -1))
# Out:
# array([[1.        , 0.92415503],
#        [0.92415503, 1.        ]])

# %%
accuracy(preds.mean(0), targs)
# Out:
# TensorCategory(0.7341)

# %%
#hide
from nbdev.export import *
from nbdev.imports import *
os.chdir(root+'/nbs_dev')
notebook2script()
